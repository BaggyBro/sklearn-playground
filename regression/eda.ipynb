# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_dir = "data/housing.csv"
df = pd.read_csv(dataset_dir)
df
# Out:
#        Unnamed: 0          id  ... sqft_living15  sqft_lot15
# 0               0  7129300520  ...          1340        5650
# 1               1  6414100192  ...          1690        7639
# 2               2  5631500400  ...          2720        8062
# 3               3  2487200875  ...          1360        5000
# 4               4  1954400510  ...          1800        7503
# ...           ...         ...  ...           ...         ...
# 21608       21608   263000018  ...          1530        1509
# 21609       21609  6600060120  ...          1830        7200
# 21610       21610  1523300141  ...          1020        2007
# 21611       21611   291310100  ...          1410        1287
# 21612       21612  1523300157  ...          1020        1357
#
# [21613 rows x 22 columns]

# %%
df.shape
# Out:
# (21613, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     21613 non-null  int64
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  object
#  3   price          21613 non-null  float64
#  4   bedrooms       21600 non-null  float64
#  5   bathrooms      21603 non-null  float64
#  6   sqft_living    21613 non-null  int64
#  7   sqft_lot       21613 non-null  int64
#  8   floors         21613 non-null  float64
#  9   waterfront     21613 non-null  int64
#  10  view           21613 non-null  int64
#  11  condition      21613 non-null  int64
#  12  grade          21613 non-null  int64
#  13  sqft_above     21613 non-null  int64
#  14  sqft_basement  21613 non-null  int64
#  15  yr_built       21613 non-null  int64
#  16  yr_renovated   21613 non-null  int64
#  17  zipcode        21613 non-null  int64
#  18  lat            21613 non-null  float64
#  19  long           21613 non-null  float64
#  20  sqft_living15  21613 non-null  int64
#  21  sqft_lot15     21613 non-null  int64
# dtypes: float64(6), int64(15), object(1)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#         Unnamed: 0            id  ...  sqft_living15     sqft_lot15
# count  21613.00000  2.161300e+04  ...   21613.000000   21613.000000
# mean   10806.00000  4.580302e+09  ...    1986.552492   12768.455652
# std     6239.28002  2.876566e+09  ...     685.391304   27304.179631
# min        0.00000  1.000102e+06  ...     399.000000     651.000000
# 25%     5403.00000  2.123049e+09  ...    1490.000000    5100.000000
# 50%    10806.00000  3.904930e+09  ...    1840.000000    7620.000000
# 75%    16209.00000  7.308900e+09  ...    2360.000000   10083.000000
# max    21612.00000  9.900000e+09  ...    6210.000000  871200.000000
#
# [8 rows x 21 columns]

# %%
df.drop(columns=["Unnamed: 0", "id"], inplace=True)

# %%
df["date"] = pd.to_datetime(df["date"])
df["year_sold"] = df["date"].dt.year
df["month_sold"] = df["date"].dt.month

# %%
df.drop(columns=["date"], inplace=True)

# %%
df = df.dropna()

# %%
df.isnull().sum(), df.duplicated().sum()
# Out:
# (price            0
#  bedrooms         0
#  bathrooms        0
#  sqft_living      0
#  sqft_lot         0
#  floors           0
#  waterfront       0
#  view             0
#  condition        0
#  grade            0
#  sqft_above       0
#  sqft_basement    0
#  yr_built         0
#  yr_renovated     0
#  zipcode          0
#  lat              0
#  long             0
#  sqft_living15    0
#  sqft_lot15       0
#  year_sold        0
#  month_sold       0
#  dtype: int64,
#  np.int64(2))

# %%
df.drop_duplicates(inplace=True)
# Out:
# /tmp/ipykernel_31697/3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
plt.figure()
plt.hist(df["price"], bins=50)
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Price distribution")
plt.show()

# %%
plt.figure()
plt.boxplot(df["price"], vert=False)
plt.title("Price Boxplot")
plt.show()

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  sqft_lot15  year_sold  month_sold
# 0      221900.0       3.0       1.00  ...        5650       2014          10
# 1      538000.0       3.0       2.25  ...        7639       2014          12
# 2      180000.0       2.0       1.00  ...        8062       2015           2
# 3      604000.0       4.0       3.00  ...        5000       2014          12
# 4      510000.0       3.0       2.00  ...        7503       2015           2
# ...         ...       ...        ...  ...         ...        ...         ...
# 21608  360000.0       3.0       2.50  ...        1509       2014           5
# 21609  400000.0       4.0       2.50  ...        7200       2015           2
# 21610  402101.0       2.0       0.75  ...        2007       2014           6
# 21611  400000.0       3.0       2.50  ...        1287       2015           1
# 21612  325000.0       2.0       0.75  ...        1357       2014          10
#
# [21595 rows x 21 columns]

# %%
df["log_price"] = np.log(df["price"])
plt.figure()
plt.hist(df["log_price"], bins=50)
plt.title("Log Transformed Price")
plt.show()
# Out:
# /tmp/ipykernel_31697/1959572516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_price"] = np.log(df["price"])

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  year_sold  month_sold  log_price
# 0      221900.0       3.0       1.00  ...       2014          10  12.309982
# 1      538000.0       3.0       2.25  ...       2014          12  13.195614
# 2      180000.0       2.0       1.00  ...       2015           2  12.100712
# 3      604000.0       4.0       3.00  ...       2014          12  13.311329
# 4      510000.0       3.0       2.00  ...       2015           2  13.142166
# ...         ...       ...        ...  ...        ...         ...        ...
# 21608  360000.0       3.0       2.50  ...       2014           5  12.793859
# 21609  400000.0       4.0       2.50  ...       2015           2  12.899220
# 21610  402101.0       2.0       0.75  ...       2014           6  12.904459
# 21611  400000.0       3.0       2.50  ...       2015           1  12.899220
# 21612  325000.0       2.0       0.75  ...       2014          10  12.691580
#
# [21595 rows x 22 columns]

# %%
numerical_cols = [
    "bedrooms", "bathrooms", "sqft_living", "sqft_lot", "floors",
    "sqft_above", "sqft_basement", "yr_built", "yr_renovated",
    "lat", "long", "sqft_living15", "sqft_lot15"
]

# %%
df[numerical_cols].hist(bins=30, figsize=(15,12))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
df[numerical_cols].boxplot(rot=90)
plt.show()

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  year_sold  month_sold  log_price
# 0      221900.0       3.0       1.00  ...       2014          10  12.309982
# 1      538000.0       3.0       2.25  ...       2014          12  13.195614
# 2      180000.0       2.0       1.00  ...       2015           2  12.100712
# 3      604000.0       4.0       3.00  ...       2014          12  13.311329
# 4      510000.0       3.0       2.00  ...       2015           2  13.142166
# ...         ...       ...        ...  ...        ...         ...        ...
# 21608  360000.0       3.0       2.50  ...       2014           5  12.793859
# 21609  400000.0       4.0       2.50  ...       2015           2  12.899220
# 21610  402101.0       2.0       0.75  ...       2014           6  12.904459
# 21611  400000.0       3.0       2.50  ...       2015           1  12.899220
# 21612  325000.0       2.0       0.75  ...       2014          10  12.691580
#
# [21595 rows x 22 columns]

# %%
categorical_cols = ["waterfront", "view", "condition", "grade", "zipcode"]

for col in categorical_cols:
    plt.figure()
    df[col].value_counts().sort_index().plot(kind="bar")
    plt.title(f"{col} Distribution")
    plt.show()

# %%
corr_matrix = df.corr()

plt.figure(figsize=(12,10))
plt.imshow(corr_matrix, cmap="coolwarm")
plt.colorbar()
plt.title("Correlation Matrix")
plt.show()

# %%
corr_matrix["price"].sort_values(ascending=False)
# Out:
# price            1.000000
# log_price        0.891718
# sqft_living      0.701907
# grade            0.668014
# sqft_above       0.605359
# sqft_living15    0.585238
# bathrooms        0.525908
# view             0.397314
# sqft_basement    0.323788
# bedrooms         0.308762
# lat              0.306772
# waterfront       0.266437
# floors           0.256906
# yr_renovated     0.126409
# sqft_lot         0.089871
# sqft_lot15       0.082823
# yr_built         0.054036
# condition        0.036003
# long             0.022056
# year_sold        0.003802
# month_sold      -0.009999
# zipcode         -0.053419
# Name: price, dtype: float64

# %%
important_features = ["sqft_living", "bathrooms", "grade", "sqft_above"]

for col in important_features:
    plt.figure()
    plt.scatter(df[col], df["price"], alpha=0.3)
    plt.xlabel(col)
    plt.ylabel("Price")
    plt.title(f"Price vs {col}")
    plt.show()
